# %%
# Pulling data from the BOC to build macroeconomic charts
# Resource: https://www.askpython.com/python/examples/pull-data-from-an-api

# BOC API pulls begin with https://www.bankofcanada.ca/valet/
# INDEX OF API CODES
# Total CPI = v41690973 
# Total CPI (seasonally adjusted) = v41690914 
# Total CPI change over last 12 months = v41690973


import requests

response_api = requests.get('https://www.bankofcanada.ca/valet/observations/v41690973/csv')
data = response_api.text
print(response_api)
print(data)
# Out:
# <Response [200]>
# ﻿"TERMS AND CONDITIONS"
# "https://www.bankofcanada.ca/terms/"
#
# "SERIES"
# "id","label","description"
# "V41690973","Total CPI","Total CPI"
#
# "OBSERVATIONS"
# "date","V41690973"
# "1995-01-01","86.6"
# "1995-02-01","87.0"
# "1995-03-01","87.2"
# "1995-04-01","87.5"
# "1995-05-01","87.7"
# "1995-06-01","87.7"
# "1995-07-01","87.9"
# "1995-08-01","87.7"
# "1995-09-01","87.8"
# "1995-10-01","87.7"
# "1995-11-01","88.0"
# "1995-12-01","87.8"
# "1996-01-01","88.0"
# "1996-02-01","88.1"
# "1996-03-01","88.5"
# "1996-04-01","88.7"
# "1996-05-01","89.0"
# "1996-06-01","89.0"
# "1996-07-01","89.0"
# "1996-08-01","89.0"
# "1996-09-01","89.1"
# "1996-10-01","89.3"
# "1996-11-01","89.7"
# "1996-12-01","89.7"
# "1997-01-01","89.9"
# "1997-02-01","90.1"
# "1997-03-01","90.2"
# "1997-04-01","90.2"
# "1997-05-01","90.3"
# "1997-06-01","90.5"
# "1997-07-01","90.5"
# "1997-08-01","90.6"
# "1997-09-01","90.6"
# "1997-10-01","90.6"
# "1997-11-01","90.5"
# "1997-12-01","90.4"
# ...
